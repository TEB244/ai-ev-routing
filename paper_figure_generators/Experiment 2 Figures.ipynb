# %% [markdown]
# ### Imports

# %%
import sys
import os
sys.path.append(os.path.abspath('../'))

import pandas as pd

import random
from datetime import datetime

# %% [markdown]
# ### Config

# %%
colors = {
    "DQN": 'darkorange',
    "REINFORCE": 'forestgreen',
    "ODT": 'blueviolet',
    "CMA": 'turquoise',
    "CMA-ES": 'turquoise'
}

season_colors = {
    "winter": 'blue',
    "spring": 'forestgreen',
    "summer": 'gold',
    "autumn": 'darkorange'
}

exp_lists_preformatted = [
    '4000_4179.csv', '5000_5179.csv', '6000_6179.csv', '4108_4179.csv', '5108_5179.csv', '6108_6179.csv'
] # Existing formatted datasets

# %% [markdown]
# ## Table 1

# %% [markdown]
# ### Loading data

# %%
# Define the file path with starting_exp and ending_exp variables
file_path_for_processed_data = f'../../../../storage_1/metrics/formatted_experiment_data/part_4/'

if len(exp_lists_preformatted) > 0:
    agent_dataframes = []
    
    # Load and combine datasets
    for existing_set in exp_lists_preformatted:
        loaded_dataset = pd.read_csv(f"{file_path_for_processed_data}/agent_{existing_set}")
        # Combine datasets
        agent_dataframes.append(loaded_dataset)

    cumulative_agent_df = pd.concat(agent_dataframes, ignore_index=True)

    station_dataframes = []
    
    # Load and combine datasets
    for existing_set in exp_lists_preformatted:
        loaded_dataset = pd.read_csv(f"{file_path_for_processed_data}/station_{existing_set}")
        # Combine datasets
        station_dataframes.append(loaded_dataset)

    cumulative_station_df = pd.concat(station_dataframes, ignore_index=True)

# %% [markdown]
# ### Printing data for table

# %%
algos = cumulative_agent_df['algorithm'].unique()

# Determine list of seasons (only needed if load_agent or load_station)
seasons = sorted(cumulative_agent_df['season'].unique())

results = []

for algo in algos:
    print(f"===== Algorithm: {algo} =====\n")

    if seasons is not None:
        for season in seasons:
            print(f"  Season: {season}")
            a_season = cumulative_agent_df[
                (cumulative_agent_df['algorithm'] == algo) &
                (cumulative_agent_df['season'] == season)
            ]
            if not a_season.empty:
                print("    Agent:")
                print(f"      Avg Distance : {a_season['distance_traveled'].mean():.2f}")
                print(f"      Dist Std Dev : {a_season['distance_traveled'].std():.2f}")
                print(f"      Avg Energy Used (Wh)  : {a_season['battery_used'].mean():.2f}")
                print(f"      Energy Std Dev (Wh) : {a_season['battery_used'].std():.2f}")
                print(f"      Avg Reward   : {a_season['reward'].mean():.2f}")
                print(f"      Reward Std   : {a_season['reward'].std():.2f}")

            s_season = cumulative_station_df[
                (cumulative_station_df['algorithm'] == algo) &
                (cumulative_station_df['season'] == season)
            ]
            if not s_season.empty:
                print("    Station:")
                print(f"      Max Traffic   : {s_season['traffic'].max():.2f}")
                print(f"      Traffic Std   : {s_season['traffic'].std():.2f}")
            print()  # blank line between seasons

            results.append([algo, season, a_season['distance_traveled'].mean(), a_season['distance_traveled'].std(), a_season['battery_used'].mean(), a_season['battery_used'].std(), s_season['traffic'].max()])

    print("\n")  # extra space between algorithms

results_df = pd.DataFrame(results, columns=["Algorithm", "Season", "Avg Distance", "Distance Std Dev", "Avg Energy Used (Wh)", "Energy Used Std Dev (Wh)", "Peak Traffic"])
results_df.to_csv('./table_data/table_1.csv', index=False)
# Out:
# ===== Algorithm: DQN =====
#
#   Season: autumn
#     Agent:
#       Avg Distance : 37.11
#       Dist Std Dev : 1.52
#       Avg Energy Used (Wh)  : 21325.77
#       Energy Std Dev (Wh) : 3103.67
#       Avg Reward   : -63.29
#       Reward Std   : 6.06
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.03
#
#   Season: spring
#     Agent:
#       Avg Distance : 37.12
#       Dist Std Dev : 1.52
#       Avg Energy Used (Wh)  : 17572.16
#       Energy Std Dev (Wh) : 3155.58
#       Avg Reward   : -64.55
#       Reward Std   : 6.17
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.03
#
#   Season: summer
#     Agent:
#       Avg Distance : 37.11
#       Dist Std Dev : 1.52
#       Avg Energy Used (Wh)  : 22786.93
#       Energy Std Dev (Wh) : 3075.07
#       Avg Reward   : -62.89
#       Reward Std   : 6.04
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.02
#
#   Season: winter
#     Agent:
#       Avg Distance : 37.14
#       Dist Std Dev : 1.55
#       Avg Energy Used (Wh)  : 15831.54
#       Energy Std Dev (Wh) : 3287.53
#       Avg Reward   : -65.78
#       Reward Std   : 6.59
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.05
#
#
#
# ===== Algorithm: REINFORCE =====
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.70
#       Dist Std Dev : 0.92
#       Avg Energy Used (Wh)  : 21198.31
#       Energy Std Dev (Wh) : 3006.10
#       Avg Reward   : -62.49
#       Reward Std   : 3.42
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.91
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.71
#       Dist Std Dev : 0.93
#       Avg Energy Used (Wh)  : 18520.81
#       Energy Std Dev (Wh) : 3696.46
#       Avg Reward   : -64.43
#       Reward Std   : 4.00
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.93
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.70
#       Dist Std Dev : 0.91
#       Avg Energy Used (Wh)  : 22543.93
#       Energy Std Dev (Wh) : 2927.18
#       Avg Reward   : -61.57
#       Reward Std   : 3.71
#     Station:
#       Max Traffic   : 23.00
#       Traffic Std   : 1.88
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.73
#       Dist Std Dev : 0.99
#       Avg Energy Used (Wh)  : 15288.12
#       Energy Std Dev (Wh) : 2993.39
#       Avg Reward   : -64.92
#       Reward Std   : 4.05
#     Station:
#       Max Traffic   : 24.00
#       Traffic Std   : 1.96
#
#
#
# ===== Algorithm: CMA =====
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.87
#       Dist Std Dev : 1.26
#       Avg Energy Used (Wh)  : 21546.68
#       Energy Std Dev (Wh) : 3048.11
#       Avg Reward   : -72.66
#       Reward Std   : 5.38
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.02
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.27
#       Avg Energy Used (Wh)  : 17950.97
#       Energy Std Dev (Wh) : 3194.71
#       Avg Reward   : -74.44
#       Reward Std   : 5.65
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.06
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.89
#       Dist Std Dev : 1.28
#       Avg Energy Used (Wh)  : 22908.79
#       Energy Std Dev (Wh) : 2962.42
#       Avg Reward   : -71.77
#       Reward Std   : 5.31
#     Station:
#       Max Traffic   : 24.00
#       Traffic Std   : 1.98
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.90
#       Dist Std Dev : 1.31
#       Avg Energy Used (Wh)  : 15961.86
#       Energy Std Dev (Wh) : 3186.76
#       Avg Reward   : -75.83
#       Reward Std   : 5.42
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.09
#
#
#
# ===== Algorithm: ODT =====
#
#   Season: autumn
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.19
#       Avg Energy Used (Wh)  : 21198.23
#       Energy Std Dev (Wh) : 3009.29
#       Avg Reward   : -61.55
#       Reward Std   : 4.70
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.96
#
#   Season: spring
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.19
#       Avg Energy Used (Wh)  : 17573.25
#       Energy Std Dev (Wh) : 3151.81
#       Avg Reward   : -62.48
#       Reward Std   : 4.74
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 1.95
#
#   Season: summer
#     Agent:
#       Avg Distance : 36.88
#       Dist Std Dev : 1.18
#       Avg Energy Used (Wh)  : 22543.25
#       Energy Std Dev (Wh) : 2928.91
#       Avg Reward   : -61.10
#       Reward Std   : 4.49
#     Station:
#       Max Traffic   : 25.00
#       Traffic Std   : 1.96
#
#   Season: winter
#     Agent:
#       Avg Distance : 36.90
#       Dist Std Dev : 1.23
#       Avg Energy Used (Wh)  : 15365.26
#       Energy Std Dev (Wh) : 3034.30
#       Avg Reward   : -63.80
#       Reward Std   : 4.82
#     Station:
#       Max Traffic   : 26.00
#       Traffic Std   : 2.01
